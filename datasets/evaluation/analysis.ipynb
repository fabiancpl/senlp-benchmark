# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ### Load the data

# %%
tasks_df = pd.read_csv("../../assets/tasks.csv")

# %% [markdown]
# ### Visualize the data

# %%
fig, ax = plt.subplots(figsize=(5, 4))
sns.barplot(
    tasks_df.groupby("Activity")["Task ID"].count().reset_index().rename(columns={"Task ID": "# Tasks"}),
    x="Activity", y="# Tasks", hue="Activity",
    order=["Requirements", "Development", "Quality assurance", "Maintenance", "Management"],
    palette=["#17becf", "#ff7f0e", "#2ca02c", "#d62728", "#9467bd"]
)
plt.xticks(rotation=45, ha="right", rotation_mode="anchor")
new_labels = ["Requirements\nanalysis", "Software\ndevelopment", "Quality\nassurance", "Software\nmaintenance", "Software\nmanagement"]
ax.set_xticklabels(new_labels, rotation=45, ha="right", rotation_mode="anchor")
ax.set_xlabel("Activity   ", labelpad=0) 
# plt.rcParams['font.size'] = 10

plt.tight_layout()

plt.savefig("tasks_per_activity.pdf", format="pdf", bbox_inches="tight")

plt.show()
# Out:
# /tmp/ipykernel_2432548/215602685.py:10: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(new_labels, rotation=45, ha="right", rotation_mode="anchor")
